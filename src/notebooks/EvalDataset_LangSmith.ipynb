# %% [markdown]
# # Creating the evaluation Dataset with Langsmith

# %%
import os
import re 
import json
import importlib
import pandas as pd
from dotenv import load_dotenv
from langsmith import Client, evaluate
from phenopy.score import Scorer
from langsmith.schemas import Run, Example
from phenopy.build_hpo import generate_annotated_hpo_network
import sys
sys.path.append('../utils')
import customchain as cc
custom_chain = cc.custom_chain

# %%
importlib.reload(cc)
custom_chain = cc.custom_chain

# %%
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# Creación de los datasets de RAG-HPO y GSC

# %%
client = Client()

# %%
df = pd.read_csv('../../datasets/RAG-HPO/Test_Cases.csv')
df["annotations"] = df.annotations.apply(eval)
df = df.rename(columns={'esp':'clinical_note'})
input_keys = ['clinical_note']
output_keys = ['annotations'] 

dataset = client.upload_dataframe(
    df=df,
    input_keys=input_keys,
    output_keys=output_keys,
    name="RAG-HPO eval dataset",
    description="Dataset en español para la evaluación de herramientas de codificación fenotípica.",
    data_type="kv" # The default
)

# %%
RESOURCES_DIR="../../resources"
with open(os.path.join(RESOURCES_DIR, "hpo_es.json"), "r") as fp:
    hpo = json.load(fp)
valid_ids = [x['id'] for x in hpo]

# %%
def process_output(output):
    hpo_list = output["annotations"]
    hpo_list = [s.strip() for s in hpo_list]
    hpo_list = [j for j in hpo_list if re.compile(r"^HP:\d{7}$").match(j)]
    hpo_list = [i for i in hpo_list if i in valid_ids]
    return {"annotations":hpo_list}

# %%
examples = client.list_examples(dataset_name="RAG-HPO eval dataset")
ids = []
metadata = []
inputs = []
outputs = []
for example in examples:
    ids.append(example.id)
    inputs.append(example.inputs)
    outputs.append(process_output(example.outputs))

# %%
client.update_examples(
    dataset_name="RAG-HPO eval dataset",
    example_ids = ids,
    inputs = inputs, 
    outputs = outputs
    )
# Out:
# {'message': '116 examples updated',
#  'example_ids': ['1a31bc86-a17e-4418-b3b4-6579196276e1',
#   'd13a3ff3-2648-40b5-abe7-bf6d293b2cc8',
#   'f19e2e38-e276-4f58-8508-359a659b5627',
#   'af36f449-a848-4b5f-b9dc-4bae9629d2b5',
#   'afd089c8-5bcb-4f8f-a14b-0d4eea654e0f',
#   'bee473dd-6c83-4252-a51d-93679494c278',
#   'fdcb4fa3-05dc-4bf6-8bbf-7b6d66465cf4',
#   '2e6b74d0-35e6-45d6-83dd-b293615d85f1',
#   '7a4edacb-b36a-4d93-9ef5-8703c8d166a0',
#   '7faf2fb6-33ab-4088-adb6-605c0b1b3b4c',
#   'a0975ca7-2f93-4d88-abfb-66b79014f06b',
#   'a5270446-3024-4136-949b-dc5413854718',
#   'a58f8dcc-b7ff-43e5-b38f-ee4a11c3cbe9',
#   '512b9043-57c0-43ee-ba35-77eeec30e534',
#   '7a0f7dec-d7cd-4c0c-8933-ced77b7f4cf8',
#   '7f8644d2-54cb-4cfd-8462-f9f96dd09559',
#   '78f7deb4-368a-49af-af0a-ee97b7113e71',
#   '9ab0333b-c04d-4a19-a846-376864f069fd',
#   'd0ce413e-db89-4eb6-b6bb-831abd03e62a',
#   '256756a1-a92a-4946-87bb-ffb8333cf686',
#   '36dcb0ab-aed4-4608-bd68-f63ee73edbd4',
#   '54c6fd9d-fe8a-440b-b02e-68742fb13b7f',
#   '3ff386a6-24c0-4c26-9b5a-68443733dd96',
#   '48f63d40-5017-4eb1-b119-06284f7e2338',
#   'c37b6dbf-7394-4797-bb3a-695b99ac7ca8',
#   '11c0c180-5323-4db7-8bb5-35d7440fb4e0',
#   'a3bce47c-fba4-4081-8797-4a1aa542b9ec',
#   'ff9100cb-e7dc-46bb-a204-a88a874c6da5',
#   '079ba94e-b13e-4445-a976-5534591b50f4',
#   'f94202cf-96e9-4e1d-9735-7f06e1a3d3e8',
#   '4adf8607-d0d7-4e1c-a770-4cb9a7dc265b',
#   'e3299d49-ccca-45cb-8288-a242ccf216d4',
#   'fee898bb-87e2-4fea-9166-6c7b0200a018',
#   '74752b74-de61-4147-b326-9360cbd620d0',
#   '937d20bc-acbb-4676-988e-9e3621f663b6',
#   '26b5fa65-9ca8-4ccb-b60c-2157d852352f',
#   '49224c1c-2118-4227-bb51-6129739b33f1',
#   '6db14185-9805-416d-852d-5ebf66cac4a4',
#   '3e3915fa-06ca-428f-b3db-e2d8a1ca2cb3',
#   '1d921b0f-82d8-41a9-a19c-346ea10b8f38',
#   '2864ef02-0542-48ab-a5b8-b4ca35f5725e',
#   '3807f14c-3fbe-4543-a4df-149fe75a2712',
#   '04264f8e-be4e-437b-a0bb-84288e5cf73a',
#   '8aa46f71-518c-453a-a9bf-0fdf159b5885',
#   '12cb42d2-a1a3-4e37-bda7-0083aaff5b41',
#   '3439caa3-d373-4f2d-8907-e56c5a245bd8',
#   '5292e1b9-a55b-4d1a-b141-784e512fdb9e',
#   '2ca92cdb-9498-4051-b2fe-fe35ac7df976',
#   '493bada7-46df-4dc2-a8e6-9bd4b5c17f44',
#   'f17f159f-3ba7-46f7-84d2-854b3f6bb3ec',
#   '1c084e11-266a-4ae8-b1c2-bbbc6c384875',
#   'a9c8789b-ecc2-42a5-ab55-f978250fe306',
#   'dbe0a5cb-7408-4070-a0a1-3c7a1a458039',
#   '1e850673-06ab-4dde-95a5-6ed0b83a5440',
#   '2d90fe7b-cd30-4ed7-afa8-5081eb228d53',
#   '4755f4d4-e061-4e71-84c5-db23f49f5752',
#   '5d915ecd-f601-4e0d-99de-69f6cad1aae9',
#   '5f8b6693-f1cb-40bf-9ad0-e829a3099a63',
#   '0497c3d2-f197-4959-824f-f22df0c38266',
#   '0a256481-1522-4425-ac55-9684af781edd',
#   '1a0b6813-9cca-4f15-9514-38f932259ebd',
#   '80c9354e-703b-4652-a2ed-cc3364012e49',
#   'dc29292d-4a95-4ec4-8ee9-9db159d25f11',
#   'a8e16975-34c8-4e7d-8e59-5639f670644d',
#   'e304f43c-43a6-4bd7-a3db-e49458ad5ff1',
#   '2f45d980-3d5f-45cc-bff3-4cf00fa812a2',
#   '56bb2bbe-6a4d-4e87-b87a-6621380e96b8',
#   '7785f187-31b0-42e3-823d-ecb37188ef80',
#   'c77fe607-8537-4d22-a60d-801b654abfe8',
#   'df032e35-ba3c-48c1-8d1f-00fa7acc58ba',
#   'ea8d9881-ba6f-45ab-b37f-ae48054e0435',
#   '4c85680a-10e1-4ddb-a3a7-a87333b1722a',
#   '5752faca-8376-49b0-9bda-c497fda99f6c',
#   '5bb6e984-0c98-4f6e-87ad-26626830e0cb',
#   'd168f105-a867-43ec-a1f7-319547e0c5e6',
#   'de9ff14a-48bf-4a53-a13c-66a522557a45',
#   'f2e8d27c-d89b-443f-856c-5f597faf5489',
#   '23a673b1-39fc-4c78-931e-51bb93dbee50',
#   '42a42358-4311-4fc7-b0ba-5761a782305f',
#   '6d8d359f-91f3-4ccb-b574-0e5e2cea71f8',
#   'fb5b74e9-41c7-439a-b9a3-fe189a7dd702',
#   '75366096-e01b-4690-b70b-447ab2bb63f9',
#   'be77dea1-0370-4d6b-b16c-f174551a7bae',
#   'e193b2cd-b789-4171-a654-c025beaf276c',
#   'ef022edc-d0c5-453c-a9db-9ce6a8099490',
#   '1c9acd02-7c4a-42f3-ab39-679a7fad2d2b',
#   '454fbb8e-0e18-40e4-82e5-610494d43526',
#   '72dfeba4-6ef9-4eee-8f7f-c323f7db7a38',
#   'cea0236d-270c-4dd4-92ac-fef6d7c3fbb0',
#   'fcda2492-07b2-4053-9e1a-2cd7df4fb67a',
#   '1dc1fa15-0069-4ec0-8fe4-f1b2d9ee1b40',
#   '81030eaf-91b1-47e9-b2b3-e5e29ec01cce',
#   'a593bc86-e62d-46c5-9998-08dc2771e980',
#   '0984c2d4-ea67-4588-8ab3-b05dcdd38106',
#   '37f4a46d-2dc3-4580-a88d-504443dd31ff',
#   '72c7f996-e7b5-4ed6-9545-d244b81e5794',
#   '9bc1953b-1021-4fcd-af88-b2d4bceda44d',
#   'b06c1183-7ed9-488e-bf6d-a7d400ff2ff2',
#   '5ad997c8-1e94-4bf5-85fc-05bdcf60b300',
#   '892ed05a-1f95-493a-9fd2-cdc8fc928442',
#   'a6cb502f-9549-4f72-9b04-d96bc7aade00',
#   '603fecb0-bcc5-41ee-bbcb-4f94b279caa6',
#   'd1a9a894-05ab-4fd0-bd39-6253b051c7d2',
#   '7b8164cb-3326-4d1a-a4d2-95755b2352bc',
#   '981eb8d0-7eeb-4377-bdd9-f0843c5b8110',
#   'aa3c2508-a5f2-45bd-a25b-23645cd350b2',
#   '236270f7-a563-4e65-9a01-03870596b7cb',
#   '72b13581-92d8-4c17-adc8-fda79e1a1e70',
#   '79d41af4-4fb6-4d7c-b670-2c33a693f5c2',
#   'ede8ba11-566f-46f5-a0d9-f430d482c0c6',
#   'f1809014-60b7-4751-b255-9af533025652',
#   '390aee13-6e21-4462-87e7-5438a4af06f7',
#   'bf2295ee-1815-4cf8-a4ee-6b971953d954',
#   'ec5ad56a-295f-49c3-bda7-415185b182dc',
#   '9fb906c1-a2e4-4f49-a072-511a307ae70f',
#   'd4353fb1-d7e4-4085-bbc1-bb66006eea95'],
#  'count': 116}

# %%
texts = []
annotations = []
for file in os.listdir("../../datasets/GCS+_ESP/Text"):
    with open(os.path.join("../../datasets/GCS+_ESP/Text", file), "r") as fp:
        texts.append(fp.read())
    annots = pd.read_csv(os.path.join("../../datasets/GSC+/Annotations", file), header=None, sep="\t")
    annots[1] = annots[1].apply(lambda x: x.split("|")[0].strip())
    annotations.append(annots[1].to_list())

# %%
gcs_esp = pd.DataFrame({"esp":texts, "annotations":annotations})

# %%
input_keys = ['esp']
output_keys = ['annotations'] 

dataset = client.upload_dataframe(
    df=gcs_esp,
    input_keys=input_keys,
    output_keys=output_keys,
    name="GSC eval dataset",
    description="Dataset en español para la evaluación de herramientas de codificación fenotípica.",
    data_type="kv" # The default
)

# %% [markdown]
# Definición de las métricas

# %%
def clean_final_answer(outputs):
    return [code.hpo_code.strip() for code in outputs["final answer"]]

# %%
phenopy_data_directory = "../../resources/"

# files used in building the annotated HPO network
obo_file = os.path.join(phenopy_data_directory, 'hp.obo')
disease_to_phenotype_file = os.path.join(phenopy_data_directory, 'phenotype.hpoa')

hpo_network, alt2prim, disease_records = \
    generate_annotated_hpo_network(obo_file,
                                   disease_to_phenotype_file)

scorer = Scorer(hpo_network)

# %%
# We can still pass in Run and Example objects if we'd like
def traditional_metrics(outputs: dict, reference_outputs: dict) -> list[dict]:
    """Check precision, recall and f1."""
    predicted_terms = clean_final_answer(outputs)
    real_terms = eval(reference_outputs["annotations"])
    precision = 0 if len(predicted_terms) == 0 else sum([int(term in real_terms) for term in predicted_terms]) / len(predicted_terms)
    recall = 0 if len(real_terms) == 0 else sum([int(term in predicted_terms) for term in real_terms]) / len(real_terms)
    f1 = 0 if (precision + recall) == 0 else round(2 * (precision * recall) / (precision + recall),2)

    return [
        {"key": "precision", "score": precision},
        {"key": "recall", "score": recall},
        {"key": "f1", "score": f1},
    ]

# %%
def semantic_similarity(outputs: dict, reference_outputs: dict)->float:
    """Check semantic similarity using phenopy."""
    predicted_terms = clean_final_answer(outputs)
    real_terms = eval(reference_outputs["annotations"])

    return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}

# %%
scorer.score_term_sets_basic(["HP:0033349"], ["HP:0001317"])
# Out:
# 0.0

# %%
def jaccard_similarity(outputs: dict, reference_outputs: dict)->float:
    """Check Jaccard similarity between two sets."""
    predicted_terms = set(clean_final_answer(outputs))
    real_terms = set(eval(reference_outputs["annotations"]))    
    intersection = predicted_terms.intersection(real_terms)
    union = predicted_terms.union(real_terms)
    if not union:
        return 1.0  # define similarity as 1.0 when both are empty
    return len(intersection) / len(union)

# %%
def retrieve_accuracy(outputs: dict, reference_outputs: dict)->float:
    """Check retriever accuracy and recall."""
    predicted_candidates = set().union(*outputs["docs"])
    real_terms = set(eval(reference_outputs["annotations"]))  
    recall = len(real_terms & predicted_candidates) / len(real_terms)           # = 2/2 = 1.0
    precision = len(real_terms & predicted_candidates) / len(predicted_candidates)   

    return [{"key": "r_precision", "score": precision}, 
            {"key": "r_recall", "score": recall}]

# %%
results = evaluate(
    custom_chain,
    data="RAG-HPO eval dataset",
    evaluators=[traditional_metrics, semantic_similarity, jaccard_similarity, retrieve_accuracy]
)
# Out:
# View the evaluation results for experiment: 'extraneous-stretch-87' at:
# https://smith.langchain.com/o/69013edf-2d4b-41cf-a1be-5c1e6977330d/datasets/b39bf604-8d88-4bd8-8a50-e98e9b5f7138/compare?selectedSessions=52de0f30-c683-4232-9b39-29b58293818e
# 0it [00:00, ?it/s]Error running evaluator <DynamicRunEvaluator semantic_similarity> on run 22202133-14b7-4acf-8d84-f8a65cb27423: KeyError('HP:6000040')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'HP:6000040'
# 2it [00:20,  9.96s/it]Error running evaluator <DynamicRunEvaluator semantic_similarity> on run 4b074df9-5298-4d7d-b627-063a440cfa87: KeyError('HP:0000735')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'HP:0000735'
# 6it [01:04, 11.28s/it]Error running evaluator <DynamicRunEvaluator semantic_similarity> on run b65fa4bc-4479-4d0e-9a32-fb201d202ef8: KeyError('HP:0002355')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'HP:0002355'
# 7it [01:20, 12.76s/it]Error running evaluator <DynamicRunEvaluator traditional_metrics> on run ced95a1c-c534-4adf-8a66-726d755bf378: ZeroDivisionError('float division by zero')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/369705716.py", line 8, in traditional_metrics
#     f1 = round(2 * (precision * recall) / (precision + recall),2)
#                ~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~
# ZeroDivisionError: float division by zero
# 8it [01:22,  9.51s/it]Error running evaluator <DynamicRunEvaluator traditional_metrics> on run 10cbd4b1-6e3e-435f-9b59-7f3eb6be5547: ZeroDivisionError('float division by zero')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/369705716.py", line 8, in traditional_metrics
#     f1 = round(2 * (precision * recall) / (precision + recall),2)
#                ~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~
# ZeroDivisionError: float division by zero
# 10it [01:42,  9.83s/it]Error running evaluator <DynamicRunEvaluator semantic_similarity> on run 7eaeca0a-ed54-4112-8d43-b706844d04d8: KeyError('HP:0006541')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'HP:0006541'
# 11it [01:56, 11.02s/it]Error running evaluator <DynamicRunEvaluator semantic_similarity> on run b11ee4ea-ba38-4ba8-86b9-43fd95d18569: KeyError('HP:0001317 ')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'HP:0001317 '
# 12it [02:06, 10.86s/it]Error running evaluator <DynamicRunEvaluator semantic_similarity> on run 14cfda2c-4019-41cf-9740-f08b98ae6173: KeyError('HP:0002355')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'HP:0002355'
# 13it [02:27, 13.77s/it]Error running evaluator <DynamicRunEvaluator traditional_metrics> on run ffb4a25e-20a9-42c2-a44f-07d6e960f133: ZeroDivisionError('float division by zero')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/369705716.py", line 8, in traditional_metrics
#     f1 = round(2 * (precision * recall) / (precision + recall),2)
#                ~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~
# ZeroDivisionError: float division by zero
# Error running evaluator <DynamicRunEvaluator semantic_similarity> on run ffb4a25e-20a9-42c2-a44f-07d6e960f133: KeyError('HP:0001388')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'HP:0001388'
# 14it [02:39, 13.26s/it]Error running evaluator <DynamicRunEvaluator traditional_metrics> on run 65033dac-ad68-46ca-ba3a-299c2b1f4431: ZeroDivisionError('float division by zero')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/369705716.py", line 8, in traditional_metrics
#     f1 = round(2 * (precision * recall) / (precision + recall),2)
#                ~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~
# ZeroDivisionError: float division by zero
# 16it [02:52,  9.94s/it]Error running evaluator <DynamicRunEvaluator semantic_similarity> on run 5170a6ac-d657-462c-be52-63814de9a1cd: KeyError('HP:0002355')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'HP:0002355'
# 20it [04:05, 13.95s/it]Error running evaluator <DynamicRunEvaluator semantic_similarity> on run a5a2b4fc-64be-492a-8964-a0c8a3b15d39: KeyError('HP:6000040')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'HP:6000040'
# 22it [04:29, 12.42s/it]Error running evaluator <DynamicRunEvaluator traditional_metrics> on run 5d56f995-5da8-4573-a84f-9a5b0ce358c3: ZeroDivisionError('division by zero')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/369705716.py", line 7, in traditional_metrics
#     recall = sum([int(term in predicted_terms) for term in real_terms]) / len(real_terms)
#              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~
# ZeroDivisionError: division by zero
# /Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/numpy/lib/function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Error running evaluator <DynamicRunEvaluator retrieve_accuracy> on run 5d56f995-5da8-4573-a84f-9a5b0ce358c3: ZeroDivisionError('division by zero')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1912737315.py", line 5, in retrieve_accuracy
#     recall = len(real_terms & predicted_candidates) / len(real_terms)           # = 2/2 = 1.0
#              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~
# ZeroDivisionError: division by zero
# 23it [04:33,  9.86s/it]Error running evaluator <DynamicRunEvaluator semantic_similarity> on run fb7d2293-a6a9-4736-ac5e-4af1d7343557: KeyError('HP:0033349')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'HP:0033349'
# 24it [04:46, 10.99s/it]Error running evaluator <DynamicRunEvaluator semantic_similarity> on run 5754f10f-0410-4f3e-8af3-1aa71cdf189d: KeyError('HP:0001974  ')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'HP:0001974  '
# 25it [04:49,  8.48s/it]Error running evaluator <DynamicRunEvaluator semantic_similarity> on run 534e2209-b60f-4359-a04e-d453001a1976: KeyError('none ')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'none '
# 30it [05:56, 12.94s/it]Error running evaluator <DynamicRunEvaluator traditional_metrics> on run be92f542-84d0-462b-8881-942cae9fa85e: ZeroDivisionError('float division by zero')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/369705716.py", line 8, in traditional_metrics
#     f1 = round(2 * (precision * recall) / (precision + recall),2)
#                ~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~
# ZeroDivisionError: float division by zero
# Error running evaluator <DynamicRunEvaluator semantic_similarity> on run be92f542-84d0-462b-8881-942cae9fa85e: KeyError('HP:0002757 ')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'HP:0002757 '
# 31it [06:09, 12.81s/it]Error running evaluator <DynamicRunEvaluator semantic_similarity> on run 4913bc1b-2e93-4626-8c9d-cf87e0731a9f: KeyError('HP:0001388, HP:0001382')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'HP:0001388, HP:0001382'
# 33it [06:34, 12.54s/it]Error running evaluator <DynamicRunEvaluator semantic_similarity> on run 545bb2d9-aa00-49a2-b7da-71114edf7d72: KeyError('HP:0002094, HP:0002098')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'HP:0000005'
# 90it [19:11, 16.22s/it]Error running evaluator <DynamicRunEvaluator semantic_similarity> on run 6535409f-acee-45b3-9b2c-ea5fed2c3ccf: KeyError('HP:0002355')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'HP:0002355'
# 95it [20:33, 16.57s/it]Error running evaluator <DynamicRunEvaluator traditional_metrics> on run 5c4a90ca-c978-4f9d-b9e8-f744f8c5fc79: ZeroDivisionError('float division by zero')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/369705716.py", line 8, in traditional_metrics
#     f1 = round(2 * (precision * recall) / (precision + recall),2)
#                ~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~
# ZeroDivisionError: float division by zero
# 97it [20:47, 11.57s/it]Error running evaluator <DynamicRunEvaluator semantic_similarity> on run c8e73d38-96a0-47fa-88b5-6aa51af2e534: KeyError('6000943')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: '6000943'
# 100it [21:34, 15.05s/it]Error running evaluator <DynamicRunEvaluator traditional_metrics> on run a8ca282c-940a-4a5b-82bf-c276ddbd0257: ZeroDivisionError('float division by zero')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/369705716.py", line 8, in traditional_metrics
#     f1 = round(2 * (precision * recall) / (precision + recall),2)
#                ~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~
# ZeroDivisionError: float division by zero
# 102it [21:50, 12.01s/it]Error running evaluator <DynamicRunEvaluator semantic_similarity> on run 251e2ea6-151e-4ba1-a493-1a06186af9ee: KeyError('HP:0020062  ')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'HP:0020062  '
# 109it [22:55,  9.04s/it]Error running evaluator <DynamicRunEvaluator traditional_metrics> on run 33a0aeef-6aa1-4777-81c0-bcb4e8c833c6: ZeroDivisionError('float division by zero')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/369705716.py", line 8, in traditional_metrics
#     f1 = round(2 * (precision * recall) / (precision + recall),2)
#                ~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~
# ZeroDivisionError: float division by zero
# 110it [23:01,  8.07s/it]Error running evaluator <DynamicRunEvaluator traditional_metrics> on run 0b6d1ab4-a3b8-4ae0-a12b-c659aaffa4c8: ZeroDivisionError('float division by zero')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/369705716.py", line 8, in traditional_metrics
#     f1 = round(2 * (precision * recall) / (precision + recall),2)
#                ~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~
# ZeroDivisionError: float division by zero
# Error running evaluator <DynamicRunEvaluator semantic_similarity> on run 0b6d1ab4-a3b8-4ae0-a12b-c659aaffa4c8: KeyError('HP:0002109')
# Traceback (most recent call last):
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1634, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(  # type: ignore[call-arg]
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 346, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 744, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/d6/gvk9_zmj13704s2_fj12rw680000gn/T/ipykernel_66703/1193214177.py", line 6, in semantic_similarity
#     return {"key": "semantic similarity", "score": scorer.score_term_sets_basic(predicted_terms, real_terms)}
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 316, in score_term_sets_basic
#     df = self.get_term_pair_dataframe(terms_a, terms_b)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 417, in get_term_pair_dataframe
#     [
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 418, in <listcomp>
#     (pair[0], pair[1], self.score_hpo_pair_hrss(pair[0], pair[1]))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 169, in score_hpo_pair_hrss
#     beta_ic = self.calculate_beta(term_a, term_b)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/phenopy/score.py", line 130, in calculate_beta
#     mil_ic.append(self.hpo_network.nodes[term]["ic"])
#                   ~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/malenadiazrio/Documents/UOC/TFM/TFM_2025_1/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py", line 193, in __getitem__
#     return self._nodes[n]
#            ~~~~~~~~~~~^^^
# KeyError: 'HP:0002109'
# 116it [24:06, 12.47s/it]

# %%
from langchain_chroma import Chroma
from langchain_voyageai import VoyageAIEmbeddings
embeddings_model = VoyageAIEmbeddings(model="voyage-3")
vectordb = Chroma(persist_directory="../../chroma_db/Voyage3", embedding_function=embeddings_model, 
                  collection_name="hpo_ontology_esp")
retriever = vectordb.as_retriever(search_kwargs={"k": 10})

# %%
test_df = pd.read_csv("../../datasets/TFM_test.csv")
test_df.annotations = test_df.annotations.apply(eval)
clinical_note = test_df.texts.iloc[0]
hpo_codes = test_df.annotations.iloc[0]
codigos_reales = {doc.id:doc.page_content for doc in  vectordb.get_by_ids(set(hpo_codes))}

# %%
codigos_reales
# Out:
# {'HP:0001513': 'Obesidad. Acumulación de un exceso considerable de grasa corporal.',
#  'HP:0004394': 'Pólipos gástricos múltiples.',
#  'HP:0005227': 'Poliposis colónica adenomatosa. Presencia de múltiples pólipos adenomatosos en el colon.',
#  'HP:0012183': 'Poliposis colónica hiperplásica. Presencia de múltiples pólipos hiperplásicos en el colon. Los pólipos hiperplásicos suelen tener un tamaño de unos 5 mm y muestran una proliferación hiperplásica de la mucosa.',
#  'HP:0025501': 'Obesidad clase III. Obesidad con un índice de masa corporal de 40 kg por metro cuadrado o superior.',
#  'HP:0031500': 'Masa abdominal. Agrandamiento o hinchazón anormal del abdomen.',
#  'HP:0033769': 'Poliposis de las glándulas fúndicas. Múltiples pólipos en la mucosa secretora de ácido del cuerpo gástrico y el fundus. Los pólipos de la glándula fúndica (PGF) suelen tener un tamaño de 1 a 5 mm, aunque se han encontrado pólipos de mayor tamaño. Suelen ser sésiles, brillantes, translúcidos, de color pálido a rosado (parecido al de la mucosa circundante) y a menudo presentan pequeños vasos sanguíneos superficiales. Se ha observado que, a diferencia de otros tipos de pólipos gástricos, estos pólipos se astillan o se desprenden por completo de la base cuando se extraen con pinzas frías.',
#  'HP:0100580': 'Esófago de Barrett. Cambio anormal (metaplasia) en las células de la porción inferior del esófago. El epitelio escamoso normal que recubre el esófago es sustituido por epitelio columnar metaplásico. El epitelio columnar es un tipo de célula que suele encontrarse en las partes más distales del sistema gastrointestinal.'}
